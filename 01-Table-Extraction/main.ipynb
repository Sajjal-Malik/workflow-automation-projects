# %%
import pandas as pd
import requests
import io

# %%
# Define the target website
url = "https://en.wikipedia.org/wiki/List_of_largest_banks"

# %%
# Define a custom header to mimic a standard web browser
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

# %%
# Fetch the content with the updated headers using the requests library
try:
    response = requests.get(url, headers=headers)

    # Check for other HTTP request errors
    response.raise_for_status()

    # Pass the text content of the response into pandas
    html_content = io.StringIO(response.text)
    tables = pd.read_html(html_content)

    # Output details to the terminal
    print(f"Total tables found: {len(tables)}\n")

    # Select and display the first table
    df = tables[0]
    print("--- First Table (DataFrame) Preview ---")
    print(df)

except Exception as e:
    print(f"An error occurred while fetching the page: {e}")
# Out:
# [    Rank                                Bank name  \
# 0      1  Industrial and Commercial Bank of China
# 1      2               Agricultural Bank of China
# 2      3                  China Construction Bank
# 3      4                            Bank of China
# 4      5                           JPMorgan Chase
# ..   ...                                      ...
# 95    96                  Caixa Econômica Federal
# 96    97                                SEB Group
# 97    98                          Nomura Holdings
# 98    99                     First Abu Dhabi Bank
# 99   100                      Qatar National Bank
#
#     Total assets (April 2026) (US$ billion)
# 0                                   7645.80
# 1                                   6974.82
# 2                                   6524.05
# 3                                   5484.11
# 4                                   4424.90
# ..                                      ...
# 95                                   403.70
# ...
